# %% [markdown]
# ---
# # LLM based Insight & Personalsed Content Generator
#
# This notebook describes the architecture for a model that generates property content tailored to different target audiences, e.g. (families, expats, students, investors) for use by product and marketing teams

# %% [markdown]
# ---
# # Proposed System Architecture
#
# Given differences between information that would be relevant for sales vs rentals, I would use a core central platform with listing-type-specific configuration
# * shared RAG + orchestration
# * listing-type-specific prompt templates, metrics, and guardrails
#
# <img src="images/LLM_shared_platform.png" width="1000">

# %% [markdown]
# ## High level flow
#
# 1. Input
#     * property metadata (structured)
#     * lusting type (rental/sale)
#     * target audience
#     * language/tone
# 2. Retrieval (RAG)
#     * Fetch neighborhood facts (schools, safety, public transport, amenities)
#     * Market context (rent index, vacancy, mortgage rates, price trends)
#     * POI distances (e.g supermarket) / commute times
#     * Internal policies (allowed claims, disclaimers, phrasing preferences, evidence requirements)
# 3. Fact building & configuration
#     * Compute derived metrics (e.g. rent/m² or price/m² depending on listing_type)
#     * Load listing-type-specific constraints (allowed financial fields, required disclaimers)
# 4. Content planning (LLM)
#     * Extract what matters for each audience (e.g., schools for families, yield for investors)
#     * Define structured content plan
# 5. Content generation (LLM)
#     * Generate description strictly from a provided grounding bundle
#     * Output includes fact references (citations to retrieved snippets/fields)
# 6. Validation & guardrails (Rule based, schema validator, LLM)
#     * Claim checker: ensure every numeric/location/superlative claim is supported
#     * Schema validator: ensure required sections and constraints
#     * Policy filter: block disallowed claims (“safest area”, “guaranteed ROI”) unless supported + allowed
# 7. Revision (Loop back to LLM)
#     * If validation fails, return to LLM Writer
# 8. Output
#     * Multiple descriptions
#     * Structured fact table used
#     * Confidence flags

# %% [markdown]
# ## Prompting Strategy
#
# Pipeline:
# 1. Assemble facts block (property metadata + retrieved snippets + derived metrics)
# 2. Planner prompt consumes that facts block + target audience + listing type
# 3. Planner returns a JSON plan:
#     * chosen facts (with IDs)
#     * outline/sections
#     * key messages per audience
#     * banned claims + required disclaimers
#     * style constraints
# 4. Writer prompt receives:
#     * the same facts block
#     * the planner JSON
#     * formatting rules + JSON output schema
# 5. Writer generates final description + claim/source mapping
# 6. Validator checks claims against facts_used and retrieved snippet IDs.

# %% [markdown]
# ---
# # Data Sources
#
# ## Internal listing data
#
# Source: internal databases
#
# Example fields:
# * location: city, neighborhood, coordinates
# * property type, year built, condition/renovations
# * size (m²), rooms, floor, lift, balcony
# * rent/price, oncosts, parking
# * energy rating / heating type (if available)
# * pet policy
# * furnished/unfurnished
# * availability date
# * photos
#
# ## Neighbourhood & Points of interest facts
#
# Potentital Sources:
# * public transport: https://data.opentransportdata.swiss/en/dataset/traffic-points-full
# * public transport: https://registry.opendata.aws/schweizer-haltestellen-oev/?utm_source=chatgpt.com
# * poi: open street map api: https://www.openstreetmap.org/export
#
# Example fields
# * nearby schools/daycare count + distances
# * grocery, parks, gyms, medical, nightlife
# * public transport stops + frequency proxy
# * safety proxy (e.g., “crime incidents per 1,000 residents” as a synthetic stat)
# * “quietness index” / “green space index” (synthetic)
#
# ## Market data
#
# Potential sources:
# * Federal statistic office
# * Internal databases
#
# Example reports
# * rental price index YoY and QoQ
# * vacancy rate
# * mortgage rate
# * average time-on-market
# * comparable listing ranges (by m² / n rooms)
#
# ## Macroeconomic indicators
#
# Potential sources:
# * Federal statistic office
#
# Example indicators
# * inflation rate
# * unemployment

# %% [markdown]
# ---
# # Hallucination Approach
#
# ## Grounding rules
#
# The LLM only gets given:
# * property metadata
# * retrieved neighbourhood/market snippets
# * allowed/dissallowed claims policy (e.g. dissallow "guaranteed returns")
#
# Citations are required for
# * numbers (rent index %, distances, commute times)
# * comparative phrases ("above average", "high demand")
#
# ## Post generation validation
#
# Automated checks will be implemented
# * Claim-to-source linking
#     * each claim has source_id referencing a field/snippet
# * Numeric consistency checks
#     * rent = metadata rent
#     * computed CHF/m² = rent/m² (within tolerance)
# * Entity checks
#     * neighbourhood name matches metadata
#     * POIs referenced exist in retrieved POI list
# * Style constraints
#     * avoid forbidden phrases
#     * length bounds per audience (e.g., students shorter)
#
# ## Human-in-the-loop
#
# Anything flagged low confidence goes to review
#
# Review UI shows
# * generated text
# * extracted claims
# * their sources
# * quick approve/edit

# %% [markdown]
# ---
# # Evaluation
#
# ## Automated evaluation
#
# Factuality / grounding
# * % of claims with valid source links
# * contradiction rate vs metadata
#
# Audience fit
# * A lightweight classifier or LLM-judge will evaluate the text and classify which audience is best fit, e.g it would likely look at wording like this
#     * families: schools/parks/safety/space
#     * expats: commute/international vibe/furnished/services
#     * students: transit to campus/budget/roommates
#     * investors: yield/demand/liquidity risks
#
# Readability
# * length
# * sentence complexity
# * banned terms
#
# Diversity of descriptions (if a concern)
# * n-gram overlap across the different audience outputs
#
# ## Human evaluation
#
# Marketing/product team would be used to review the outputs before final acceptance. A weekly sample might also be made
#
# Rate 1–5
# * audience alignment
# * clarity
# * compliance risk
# * would you publish this?
#
# ## Test set
# * 30–50 properties across neighborhoods and price tiers
# * Include edge cases / conflicting data:
#     * missing data
#     * studio near nightlife
#     * family home but no nearby schools
#     * investor property with high rent but high vacancy area

# %% [markdown]
# # Prototype

# %%
import os
import json
import re
from openai import OpenAI
import logging

# logger
logger = logging.getLogger()
handler = logging.StreamHandler()
handler.name = 'handler'
formatter = logging.Formatter(fmt='%(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')
handler.setFormatter(formatter)
if not logger.hasHandlers():
    logger.addHandler(handler)
logger.setLevel(logging.INFO)

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
MODEL = "gpt-5-mini"

costs = {
    "gpt-5-mini": {'input_token': 0.025, 'output_token': 2},
    "gpt-5"     : {'input_token': 0.125, 'output_token': 10}
}

def llm_cost_calculation(usage_details, model):
    model_cost = costs[model]
    
    input_tokens = usage_details.input_tokens
    output_tokens = usage_details.output_tokens
    total_tokens = usage_details.total_tokens

    input_cost = input_tokens / 1_000_000 * model_cost["input_token"]
    output_cost = output_tokens / 1_000_000 * model_cost["output_token"]
    total_cost = round(input_cost + output_cost, 2)
    
    return {
        "model": model,
        "input_tokens": input_tokens,
        "output_tokens": output_tokens,
        "total_tokens": total_tokens,
        "cost": total_cost,
    }

# %% [markdown]
# ## Simulated Property + Retrieval (RAG)

# %%
property_data = {
    "listing_type": "rental",
    "city": "Zurich",
    "neighborhood": "Wiedikon",
    "rooms": 3.5,
    "size_m2": 82,
    "balcony_m2": 7,
    "year_built": 2016,
    "elevator": True,
    "heating": "Underfloor heating",
    "rent_chf": 3150,
    "rent_per_m2": 38.4,
    "utilities_chf": 250,
    "parking_chf": 180,
    "available_from": "2026-04-01"
}

retrieved_docs = [
    {"id": "S1", "text": "Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3."},
    {"id": "S2", "text": "Nearest S-Bahn station within 650 m. Peak frequency approx every 7-10 minutes."},
    {"id": "M1", "text": "District-level vacancy estimate: 0.7%. Zurich rental index YoY +2.1%."},
    {"id": "M2", "text": "Local median advertised rent: CHF 37/m²."}
]

def build_facts_block(property_data, retrieved_docs):
    return {
        "meta": property_data,
        "retrieved": retrieved_docs
    }

facts_block = build_facts_block(property_data, retrieved_docs)
facts_block
# Out:
# {'meta': {'listing_type': 'rental',
#   'city': 'Zurich',
#   'neighborhood': 'Wiedikon',
#   'rooms': 3.5,
#   'size_m2': 82,
#   'balcony_m2': 7,
#   'year_built': 2016,
#   'elevator': True,
#   'heating': 'Underfloor heating',
#   'rent_chf': 3150,
#   'rent_per_m2': 38.4,
#   'utilities_chf': 250,
#   'parking_chf': 180,
#   'available_from': '2026-04-01'},
#  'retrieved': [{'id': 'S1',
#    'text': 'Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3.'},
#   {'id': 'S2',
#    'text': 'Nearest S-Bahn station within 650 m. Peak frequency approx every 7-10 minutes.'},
#   {'id': 'M1',
#    'text': 'District-level vacancy estimate: 0.7%. Zurich rental index YoY +2.1%.'},
#   {'id': 'M2', 'text': 'Local median advertised rent: CHF 37/m².'}]}

# %% [markdown]
# # Prompt & Schema Store

# %%
def build_planner_prompt(audience, listing_type, facts_block, tone='professional'):

    system_prompt = f"""
    You are a content planner for real-estate listings. Your job is NOT to write marketing copy.
    You must produce a structured content plan that selects which facts may be used and how they should be presented.
    You must follow the rules:
    - Use ONLY information explicitly present in the FACTS block.
    - If a desired fact is missing, do not invent it.
    - Avoid prohibited claim types (see POLICY).
    - Return valid JSON only.
    """

    user_prompt = f"""
    TASK
    Create a structured content plan for a real-estate listing description tailored to:
    - Audience: {audience}
    - Listing type: {listing_type}
    - Desired tone: {tone}
    - Language: English

    GOALS
    1) Select the most relevant facts for this audience and listing type.
    2) Produce an outline with intent for each section.
    3) Specify hard constraints for the writer: what must be cited, what must be avoided, and required disclaimers.
    4) Set length and formatting targets.

    POLICY (Prohibited / High-risk claims)
    - No guarantees (e.g., guaranteed ROI, will increase in value, risk-free)
    - No safety superlatives (e.g., safest, no crime, perfectly safe)
    - No school quality claims unless explicitly supported by a retrieved snippet (e.g., official rating)
    - No invented POIs or commute times not present in FACTS
    - Avoid subjective absolutes (e.g., best, most desirable) unless supported by retrieved ranking data

    FACTS BLOCK
    {facts_block}

    Return only JSON.
    """

    return system_prompt, user_prompt
    

def build_writer_prompt(audience, listing_type, facts_block, planner_output):

    system_prompt = f"""
    You are a real-estate copywriter. Your task is to generate marketing copy that is strictly grounded in approved facts.
    
    HARD CONSTRAINTS:
    - You may ONLY use facts explicitly listed in plan.facts_to_use.
    - If a fact is not listed in plan.facts_to_use, you must not reference it.
    - You must not introduce any new numbers, dates, distances, percentages, rankings, or named POIs.
    - Every numeric or measurable claim (CHF, %, m², km, m, minutes, dates) MUST appear in claims[] with a valid source_id.
    - The source_id must match an ID present in plan.facts_to_use.
    - Do not infer, estimate, or extrapolate values.
    - Output must be valid JSON matching the required schema.
    """

    user_prompt = f"""
    TASK
    Write a tailored listing description for:
    - Audience: {audience}
    - Listing type: {listing_type}
    - Language: English

    INPUTS
    1) FACTS BLOCK (for reference, but only allowed facts may be used):
    {facts_block}

    2) PLAN (authoritative source of allowed facts and constraints):
    {planner_output}

    STYLE REQUIREMENTS (mandatory):
    - Follow plan.style.tone.
    - Keep total word count within plan.style.length_words range.
    - Follow the exact section order defined in plan.outline.
    - Use short paragraphs.
    - Include a bullet list of highlights (3-5 bullets).

    OUTPUT REQUIREMENTS:
    Return JSON with:
    - title (string)
    - description (string)
    - highlights (array of strings)
    - claims (array of objects with claim_text and source_id)
    - facts_used (array of source_ids)

    Return only JSON.
    """

    return system_prompt, user_prompt

# %% [markdown]
# ## Planner Step

# %%
def run_planner(listing_type, audience, facts_block):


    with open('data/planner_schema.json') as f:
        planner_schema = json.load(f)

    # insert valid ids into schema
    valid_ids = (
        [f"meta.{k}" for k in facts_block["meta"].keys()] +
        [doc["id"] for doc in facts_block["retrieved"]]
    )
    planner_schema["properties"]["facts_to_use"]["items"]["enum"] = valid_ids

    system_prompt, user_prompt = build_planner_prompt(audience, listing_type, facts_block, tone='professional')

    input_messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

    response = client.responses.create(
        model=MODEL,
        input=input_messages,
        timeout=300, #seconds
        text={
            "format": {
                "type": "json_schema",
                "schema": planner_schema,
                "name": "planner_output",
                "strict": True
            }
        }
    )
    
    return response

# %%
def run_planner(listing_type, audience, facts_block):


    with open('data/planner_schema.json') as f:
        planner_schema = json.load(f)

    # insert valid ids into schema
    valid_ids = (
        [f"meta.{k}" for k in facts_block["meta"].keys()] +
        [doc["id"] for doc in facts_block["retrieved"]]
    )
    planner_schema["properties"]["facts_to_use"]["items"]["enum"] = valid_ids

    system_prompt, user_prompt = build_planner_prompt(audience, listing_type, facts_block, tone='professional')

    input_messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

    response = client.responses.create(
        model=MODEL,
        input=input_messages,
        timeout=300, #seconds
        text={
            "format": {
                "type": "json_schema",
                "schema": planner_schema,
                "name": "planner_output",
                "strict": True
            }
        }
    )
    usage = response.usage
    cost_info = llm_cost_calculation(usage, MODEL)

    planner_output = json.loads(response.output[1].content[0].text)
    return planner_output, cost_info

# %% [markdown]
# ## Writer Step

# %%
def run_writer(planner_output, facts_block):

    with open('data/writer_schema.json') as f:
        writer_schema = json.load(f)

    system_prompt, user_prompt = build_writer_prompt(audience, listing_type, facts_block, planner_output)
    input_messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

    response = client.responses.create(
        model=MODEL,
        input=input_messages,
        timeout=300, #seconds
        text={
            "format": {
                "type": "json_schema",
                "schema": writer_schema,
                "name": "planner_output",
                "strict": True
            }
        }
    )
    usage = response.usage
    cost_info = llm_cost_calculation(usage, MODEL)

    writer_output = json.loads(response.output[1].content[0].text)
    return writer_output, cost_info

# %%
test = True

listing_type = "rental"
audience = "families"

if test:
    response = run_planner(listing_type, audience, facts_block)
    planner_output, cost_info = run_planner(listing_type, audience, facts_block)
    print("\n" + "="*80)
    print(cost_info)
    display(planner_output)
    writer_output, cost_info = run_writer(planner_output, facts_block)
    print("\n" + "="*80)
    print(cost_info)
    display(writer_output)
# Out:
# 03/01/2026 05:54:16 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 05:54:48 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# ================================================================================
# {'model': 'gpt-5-mini', 'input_tokens': 900, 'output_tokens': 2406, 'total_tokens': 3306, 'cost': 0.0}
# {'audience': 'families',
#  'listing_type': 'rental',
#  'positioning': {'primary_angle': 'A modern, family-oriented 3.5-room apartment in Wiedikon (Zurich) with nearby schools, parks and frequent public transport.',
#   'secondary_angle': 'Transparent pricing and local market context to help families compare value and availability.'},
#  'outline': [{'section': 'Headline / Lead',
#    'goal': "One-sentence summary stating apartment type, neighbourhood and move-in date to capture family renters' attention."},
#   {'section': 'Key apartment facts (quick bullets)',
#    'goal': 'Present essential facts at a glance: rooms, size, balcony, floor-level features (elevator), heating, year built, rent and additional charges.'},
#   {'section': 'Family-focused features',
#    'goal': 'Highlight features important to families: room layout (3.5 rooms), balcony size, underfloor heating, elevator and year built (modern construction) — prompt reader to imagine daily life.'},
#   {'section': 'Neighborhood & local amenities',
#    'goal': 'State nearby schools and parks (counts and walking proximity) and nearest S-Bahn station distance/frequency to convey convenience for families without making unsupported claims.'},
#   {'section': 'Practical details & costs',
#    'goal': 'List monthly rent, utilities, parking charge, rent per m² and available-from date; clarify which charges are separate and included/excluded.'},
#   {'section': 'Local market context',
#    'goal': 'Briefly reference district vacancy and local rental benchmarks to help families assess availability and cost relative to the neighbourhood.'},
#   {'section': 'Call to action / Viewing info',
#    'goal': 'Request viewers to contact agent for viewings and to verify measurements/charges; remind that availability and figures should be confirmed.'}],
#  'facts_to_use': ['meta.listing_type',
#   'meta.city',
#   'meta.neighborhood',
#   'meta.rooms',
#   'meta.size_m2',
#   'meta.balcony_m2',
#   'meta.year_built',
#   'meta.elevator',
#   'meta.heating',
#   'meta.rent_chf',
#   'meta.rent_per_m2',
#   'meta.utilities_chf',
#   'meta.parking_chf',
#   'meta.available_from',
#   'S1',
#   'S2',
#   'M1',
#   'M2'],
#  'must_cite': [{'claim_type': 'nearby_schools_and_parks',
#    'rule': 'Cite S1 when stating number of primary schools within 1.2 km and number of parks within a 10-minute walk.'},
#   {'claim_type': 'public_transport_proximity_and_frequency',
#    'rule': 'Cite S2 when stating distance to the nearest S-Bahn station (within 650 m) and peak-frequency range (approx every 7-10 minutes).'},
#   {'claim_type': 'pricing_and_charges',
#    'rule': 'Cite meta.rent_chf, meta.utilities_chf and meta.parking_chf when listing monthly rent and additional monthly charges.'},
#   {'claim_type': 'apartment_specifications',
#    'rule': 'Cite meta.rooms, meta.size_m2, meta.balcony_m2, meta.year_built, meta.elevator and meta.heating when describing layout and building features.'},
#   {'claim_type': 'availability_date',
#    'rule': 'Cite meta.available_from when stating the earliest move-in date.'},
#   {'claim_type': 'local_market_context',
#    'rule': 'Cite M1 for district-level vacancy and rental index figures, and cite M2 when comparing rent per m² to the local median advertised rent.'}],
#  'must_avoid': [{'type': 'guarantees',
#    'rule': 'Do not make any guaranteed claims (e.g., guaranteed appreciation, guaranteed ROI, guaranteed demand).'},
#   {'type': 'safety_superlatives',
#    'rule': "Avoid absolute or superlative safety claims (e.g., 'safest', 'no crime', 'completely safe')."},
#   {'type': 'school_quality',
#    'rule': 'Do not claim or imply school quality or rankings unless supported by an explicit retrieved source; S1 only provides counts and walking proximity and must not be used to assert quality.'},
#   {'type': 'invented_POIs_or_times',
#    'rule': 'Do not invent points of interest, commute times or distances that are not present in the FACTS block. Only use distances/times present in S1/S2.'},
#   {'type': 'subjective_absolutes',
#    'rule': "Avoid unqualified superlatives (e.g., 'best', 'ideal for every family') unless supported by sourced ranking data."}],
#  'required_disclaimers': ['All facts, measurements and charges are based on provided information and should be verified during viewing.',
#   'Availability and listed monthly charges (rent, utilities, parking) are subject to change; confirm details with the listing agent.',
#   'Parking charge is listed separately from the monthly rent.'],
#  'style': {'tone': 'professional',
#   'length_words': [140, 220],
#   'format': 'Use a short lead sentence, a concise bulleted key-facts section, two short paragraphs for neighbourhood and practical details, and a one-line call to action.'}}
# 03/01/2026 05:56:14 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# ================================================================================
# {'model': 'gpt-5-mini', 'input_tokens': 1820, 'output_tokens': 6116, 'total_tokens': 7936, 'cost': 0.01}
# {'audience': 'families',
#  'listing_type': 'rental',
#  'title': 'Modern 3.5‑room family apartment in Wiedikon (Zurich) — available 2026-04-01',
#  'description': 'Modern 3.5-room rental apartment in Wiedikon (Zurich), available from 2026-04-01.\n\nKey apartment facts:\n- 3.5 rooms, 82 m² living space\n- 7 m² balcony\n- Built in 2016; elevator in the building; underfloor heating\n- Monthly rent CHF 3,150; utilities CHF 250; parking CHF 180 (parking charged separately)\n\nThis modern 3.5-room layout offers practical living space and a balcony for outdoor time. The building’s 2016 construction, elevator and underfloor heating support an easy daily routine for families and make moving with children and strollers straightforward.\n\nNeighborhood and transport: there are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk, supporting family life and outdoor play. The nearest S-Bahn station is within 650 m, with peak services running approximately every 7–10 minutes, providing frequent public-transport options.\n\nPractical details: monthly rent is CHF 3,150 with utilities CHF 250 and optional parking at CHF 180; the apartment’s rent equates to CHF 38.4/m² versus a local median advertised rent of CHF 37/m². District-level vacancy is estimated at 0.7% and the Zurich rental index year-on-year is +2.1%.\n\nAll facts, measurements and charges are based on provided information and should be verified during viewing. Availability and listed monthly charges (rent, utilities, parking) are subject to change; confirm details with the listing agent. Parking charge is listed separately from the monthly rent.\n\nContact the agent to arrange a viewing and to confirm measurements and charges.',
#  'highlights': ['3.5 rooms, 82 m² living space',
#   '7 m² balcony',
#   'Elevator and underfloor heating',
#   'Close to primary schools, parks and an S-Bahn station'],
#  'claims': [{'claim_text': '3.5 rooms', 'source_id': 'meta.rooms'},
#   {'claim_text': '82 m² living space', 'source_id': 'meta.size_m2'},
#   {'claim_text': '7 m² balcony', 'source_id': 'meta.balcony_m2'},
#   {'claim_text': 'Built in 2016', 'source_id': 'meta.year_built'},
#   {'claim_text': 'Elevator present in the building',
#    'source_id': 'meta.elevator'},
#   {'claim_text': 'Underfloor heating', 'source_id': 'meta.heating'},
#   {'claim_text': 'Monthly rent CHF 3,150', 'source_id': 'meta.rent_chf'},
#   {'claim_text': 'Rent per m² CHF 38.4', 'source_id': 'meta.rent_per_m2'},
#   {'claim_text': 'Utilities CHF 250 per month',
#    'source_id': 'meta.utilities_chf'},
#   {'claim_text': 'Parking CHF 180 per month', 'source_id': 'meta.parking_chf'},
#   {'claim_text': 'Available from 2026-04-01',
#    'source_id': 'meta.available_from'},
#   {'claim_text': '4 primary schools within 1.2 km', 'source_id': 'S1'},
#   {'claim_text': '3 parks within a 10-minute walk', 'source_id': 'S1'},
#   {'claim_text': 'Nearest S-Bahn station within 650 m', 'source_id': 'S2'},
#   {'claim_text': 'Peak frequency approximately every 7-10 minutes',
#    'source_id': 'S2'},
#   {'claim_text': 'District-level vacancy estimate 0.7%', 'source_id': 'M1'},
#   {'claim_text': 'Zurich rental index year-on-year +2.1%', 'source_id': 'M1'},
#   {'claim_text': 'Local median advertised rent CHF 37/m²', 'source_id': 'M2'}],
#  'facts_used': ['meta.rooms',
#   'meta.size_m2',
#   'meta.balcony_m2',
#   'meta.year_built',
#   'meta.elevator',
#   'meta.heating',
#   'meta.rent_chf',
#   'meta.rent_per_m2',
#   'meta.utilities_chf',
#   'meta.parking_chf',
#   'meta.available_from',
#   'S1',
#   'S2',
#   'M1',
#   'M2'],
#  'warnings': []}

# %% [markdown]
# ## Hallucination Validation & Evaluation

# %%
NUM_PATTERN = re.compile(
    r"(CHF\s?\d[\d,]*\.?\d*|\d+\.?\d*\s?%|\d+\.?\d*\s?m²|\d+\.?\d*\s?km|\d+\.?\d*\s?m|\d{4}-\d{2}-\d{2})"
)

def validate_output(writer_output, facts_block, planner_output=None):

    issues = []

    description = writer_output["description"]

    # All numeric mentions must be cited
    numeric_mentions = NUM_PATTERN.findall(description)
    cited_texts = [c["claim_text"] for c in writer_output["claims"]]

    for mention in numeric_mentions:
        if not any(mention in claim for claim in cited_texts):
            issues.append(f"Uncited numeric mention: {mention}")

    # Validate source ids exist
    valid_ids = (
        [f"meta.{k}" for k in facts_block["meta"].keys()] +
        [doc["id"] for doc in facts_block["retrieved"]]
    )

    snippet_map = {d["id"]: d["text"] for d in facts_block["retrieved"]}

    for claim in writer_output["claims"]:
        claim_text = claim["claim_text"]
        source_id = claim["source_id"]

        if source_id not in valid_ids:
            issues.append(f"Invalid source_id: {source_id}")
            continue

        # Meta check
        if source_id.startswith("meta."):
            field = source_id.split(".", 1)[1]
            actual_value = str(facts_block["meta"][field])

            if actual_value not in claim_text:
                issues.append(
                    f"Meta mismatch: '{claim_text}' does not contain '{actual_value}'"
                )

        # Snippet check
        else:
            snippet_text = snippet_map[source_id]

            if claim_text not in snippet_text:
                issues.append(
                    f"Claim '{claim_text}' not found in snippet {source_id}"
                )

    return issues

# %%
def compute_confidence(validation_issues):

    score = 1.0

    for issue in validation_issues:
        if "Invalid source_id" in issue:
            score -= 0.3
        elif "Uncited numeric mention" in issue:
            score -= 0.2
        elif "Meta mismatch" in issue:
            score -= 0.2
        elif "not found in snippet" in issue:
            score -= 0.15
        else:
            score -= 0.1

    return max(round(score,2), 0.0)

# %%
if test:
    validation_issues = validate_output(writer_output, facts_block)
    display(validation_issues)
    confidence_score = compute_confidence(validation_issues)
    display(confidence_score)
# Out:
# ["Meta mismatch: 'Elevator present in the building' does not contain 'True'",
#  "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'",
#  "Claim '4 primary schools within 1.2 km' not found in snippet S1",
#  "Claim '3 parks within a 10-minute walk' not found in snippet S1",
#  "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2",
#  "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1",
#  "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1",
#  "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]
# 0.0

# %% [markdown]
# # Generate Multiple Audiences

# %%
listing_type = "rental"
audiences = ["families", "expats", "students", "investors"]

results = {}
cost = 0

for audience in audiences:
    logger.info(f'Content Generation Started for: {audience}')
    planner_output, cost_info = run_planner(listing_type, audience, facts_block)
    cost += cost_info['cost']
    logger.info(f'{audience}: Planner completed')

    writer_output, cost_info = run_writer(planner_output, facts_block)
    cost += cost_info['cost']
    logger.info(f'{audience}: Writer completed')

    issues = validate_output(writer_output, facts_block)
    logger.info(f'{audience}: Validation completed')

    confidence_score = compute_confidence(validation_issues)
    logger.info(f'{audience}: Confidence score: {validation_issues}')

    results[audience] = {
        "planner": planner_output,
        "writer": writer_output,
        "validation_issues": issues,
        "validation_issues": validation_issues
    }

print(f'Total LLM cost {cost}')
results
# Out:
# 03/01/2026 06:16:26 PM Content Generation Started for: families
# 03/01/2026 06:17:03 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:17:03 PM families: Planner completed
# 03/01/2026 06:19:05 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:19:05 PM families: Writer completed
# 03/01/2026 06:19:05 PM families: Validation completed
# 03/01/2026 06:19:05 PM families: Confidence score: ["Meta mismatch: 'Elevator present in the building' does not contain 'True'", "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'", "Claim '4 primary schools within 1.2 km' not found in snippet S1", "Claim '3 parks within a 10-minute walk' not found in snippet S1", "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2", "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1", "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1", "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]
# 03/01/2026 06:19:05 PM Content Generation Started for: expats
# 03/01/2026 06:19:44 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:19:44 PM expats: Planner completed
# 03/01/2026 06:24:44 PM Retrying request to /responses in 0.493748 seconds
# 03/01/2026 06:25:19 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:25:19 PM expats: Writer completed
# 03/01/2026 06:25:19 PM expats: Validation completed
# 03/01/2026 06:25:19 PM expats: Confidence score: ["Meta mismatch: 'Elevator present in the building' does not contain 'True'", "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'", "Claim '4 primary schools within 1.2 km' not found in snippet S1", "Claim '3 parks within a 10-minute walk' not found in snippet S1", "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2", "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1", "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1", "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]
# 03/01/2026 06:25:20 PM Content Generation Started for: students
# 03/01/2026 06:25:47 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:25:47 PM students: Planner completed
# 03/01/2026 06:26:28 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:26:28 PM students: Writer completed
# 03/01/2026 06:26:28 PM students: Validation completed
# 03/01/2026 06:26:28 PM students: Confidence score: ["Meta mismatch: 'Elevator present in the building' does not contain 'True'", "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'", "Claim '4 primary schools within 1.2 km' not found in snippet S1", "Claim '3 parks within a 10-minute walk' not found in snippet S1", "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2", "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1", "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1", "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]
# 03/01/2026 06:26:28 PM Content Generation Started for: investors
# 03/01/2026 06:31:28 PM Retrying request to /responses in 0.474474 seconds
# 03/01/2026 06:36:29 PM Retrying request to /responses in 0.943950 seconds
# 03/01/2026 06:37:05 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:37:05 PM investors: Planner completed
# 03/01/2026 06:42:05 PM Retrying request to /responses in 0.408441 seconds
# 03/01/2026 06:42:54 PM HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 03/01/2026 06:42:54 PM investors: Writer completed
# 03/01/2026 06:42:54 PM investors: Validation completed
# 03/01/2026 06:42:54 PM investors: Confidence score: ["Meta mismatch: 'Elevator present in the building' does not contain 'True'", "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'", "Claim '4 primary schools within 1.2 km' not found in snippet S1", "Claim '3 parks within a 10-minute walk' not found in snippet S1", "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2", "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1", "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1", "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]
# Total LLM cost 0.07
# {'families': {'planner': {'audience': 'families',
#    'listing_type': 'rental',
#    'positioning': {'primary_angle': 'Family-friendly 3.5-room apartment in Wiedikon with nearby primary schools and parks — comfortable living space and balcony for family use.',
#     'secondary_angle': 'Modern, low-maintenance building (2016) with elevator and underfloor heating; good public transport access and transparent cost breakdown.'},
#    'outline': [{'section': 'Headline',
#      'goal': 'One-line summary that highlights key selling points for families (rooms, neighborhood, availability, monthly rent).'},
#     {'section': 'Quick facts (at-a-glance)',
#      'goal': 'List essential, verifiable facts: type, city/neighborhood, rooms, size, balcony size, year built, elevator, heating, rent, utilities, parking fee, available from.'},
#     {'section': 'Why it works for families',
#      'goal': 'Explain family-relevant features using only supported facts: number of rooms and size, balcony, proximity to primary schools and parks (cite S1).'},
#     {'section': 'Practical features & comfort',
#      'goal': 'Describe building and apartment comforts that matter to families: year built, elevator, underfloor heating, layout implication (3.5 rooms) — stick to stated facts.'},
#     {'section': 'Transport & local access',
#      'goal': 'Describe public transport access using only retrieved transport fact(s) (nearest S-Bahn station distance and peak frequency from S2).'},
#     {'section': 'Costs & availability',
#      'goal': 'Provide a transparent breakdown of monthly costs (rent, utilities, parking) and the available-from date, all cited to meta values.'},
#     {'section': 'Local market context (optional brief)',
#      'goal': 'Give short, factual context using retrieved market data (district-level vacancy and rental index from M1; local median rent from M2). Avoid market predictions or guarantees.'},
#     {'section': 'Next steps / contact prompt',
#      'goal': 'Clear call-to-action telling readers to request a viewing or contact the agent; include a required verification disclaimer.'}],
#    'facts_to_use': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'must_cite': [{'claim_type': 'monthly_rent_and_fees',
#      'rule': 'Cite meta.rent_chf, meta.utilities_chf, and meta.parking_chf for any statement of monthly costs.'},
#     {'claim_type': 'basic_property_specs',
#      'rule': 'Cite meta.rooms, meta.size_m2, meta.balcony_m2, meta.year_built, meta.elevator, and meta.heating for descriptions of layout and building features.'},
#     {'claim_type': 'availability_date',
#      'rule': 'Cite meta.available_from for any claim about when the apartment is available.'},
#     {'claim_type': 'nearby_schools_and_parks',
#      'rule': "Cite S1 for any proximity claims about primary schools and parks (examples: 'Primary schools within 1.2 km: 4', 'Parks within 10-minute walk: 3'). Do not extrapolate beyond S1 text."},
#     {'claim_type': 'public_transport_access',
#      'rule': 'Cite S2 for claims about the nearest S-Bahn station distance and peak frequency.'},
#     {'claim_type': 'market_context',
#      'rule': 'Cite M1 and M2 for district vacancy, rental index, and local median rent figures.'}],
#    'must_avoid': [{'type': 'guarantees',
#      'rule': 'Do not make any guarantees about investment performance, future rent changes, or tenancy outcomes.'},
#     {'type': 'safety_superlatives',
#      'rule': "Avoid absolute or comparative safety claims (e.g., 'safest', 'no crime', 'perfectly safe')."},
#     {'type': 'school_quality_claims',
#      'rule': 'Do not claim school quality or rankings unless directly quoting a supported snippet; S1 only provides counts and distances.'},
#     {'type': 'invented_POIs_or_commute_times',
#      'rule': 'Do not invent points of interest, exact commute times, or distances not present in the FACTS block.'},
#     {'type': 'subjective_absolutes',
#      'rule': "Avoid unqualified superlatives such as 'best' or 'most desirable' unless supported by explicit ranking data (none provided)."},
#     {'type': 'over-interpretation_of_market_data',
#      'rule': 'Do not infer future market movement or growth from the provided market snapshots.'}],
#    'required_disclaimers': ['All facts and figures are taken from the provided data and should be independently verified prior to signing any lease.',
#     'Monthly utilities and parking fees are quoted separately and subject to change; confirm exact charges with the listing agent.',
#     'Availability date is as stated (meta.available_from) and should be confirmed with the agent at inquiry.'],
#    'style': {'tone': 'professional',
#     'length_words': [140, 200],
#     'format': ''}},
#   'writer': {'audience': 'families',
#    'listing_type': 'rental',
#    'title': 'Family-friendly 3.5-room rental in Wiedikon — available 2026-04-01 at CHF 3,150/month',
#    'description': 'Headline\nFamily-friendly 3.5-room apartment in Wiedikon — available 2026-04-01 at CHF 3,150/month.\n\nQuick facts (at-a-glance)\nType: Rental in Zurich, Wiedikon. 3.5 rooms, 82 m² living space, 7 m² balcony. Built 2016. Elevator present. Heating: Underfloor heating. Rent CHF 3,150 / month; utilities CHF 250; parking CHF 180. Available from 2026-04-01.\n\nWhy it works for families\nThe 3.5-room layout and 82 m² provide clear family living space, plus a 7 m² balcony for outdoor time. Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3.\n\nPractical features & comfort\nThe building was completed in 2016 and includes an elevator. The apartment benefits from underfloor heating for even warmth and a practical 3.5-room arrangement.\n\nTransport & local access\nNearest S-Bahn station within 650 m. Peak frequency approx every 7-10 minutes.\n\nCosts & availability\nMonthly rent CHF 3,150; utilities CHF 250; parking CHF 180. Available from 2026-04-01.\n\nLocal market context\nDistrict-level vacancy estimate: 0.7%. Zurich rental index YoY: +2.1%. Local median advertised rent: CHF 37/m².\n\nNext steps / contact prompt\nRequest a viewing or contact the listing agent to learn more. All facts and figures are taken from the provided data and should be independently verified prior to signing any lease. Monthly utilities and parking fees are quoted separately and subject to change; confirm exact charges with the listing agent. Availability date is as stated (2026-04-01) and should be confirmed with the agent at inquiry.',
#    'highlights': ['3.5 rooms with 82 m² living space',
#     '7 m² balcony for family use',
#     'Primary schools within 1.2 km: 4; parks within 10-minute walk: 3',
#     'Elevator and underfloor heating; built in 2016'],
#    'claims': [{'claim_text': '3.5 rooms', 'source_id': 'meta.rooms'},
#     {'claim_text': '82 m² living space', 'source_id': 'meta.size_m2'},
#     {'claim_text': '7 m² balcony', 'source_id': 'meta.balcony_m2'},
#     {'claim_text': 'Built in 2016', 'source_id': 'meta.year_built'},
#     {'claim_text': 'Elevator present', 'source_id': 'meta.elevator'},
#     {'claim_text': 'Heating: Underfloor heating', 'source_id': 'meta.heating'},
#     {'claim_text': 'Monthly rent: CHF 3,150', 'source_id': 'meta.rent_chf'},
#     {'claim_text': 'Utilities: CHF 250', 'source_id': 'meta.utilities_chf'},
#     {'claim_text': 'Parking fee: CHF 180', 'source_id': 'meta.parking_chf'},
#     {'claim_text': 'Available from 2026-04-01',
#      'source_id': 'meta.available_from'},
#     {'claim_text': 'Primary schools within 1.2 km: 4', 'source_id': 'S1'},
#     {'claim_text': 'Parks within 10-minute walk: 3', 'source_id': 'S1'},
#     {'claim_text': 'Nearest S-Bahn station within 650 m', 'source_id': 'S2'},
#     {'claim_text': 'Peak frequency approx every 7-10 minutes',
#      'source_id': 'S2'},
#     {'claim_text': 'District-level vacancy estimate: 0.7%', 'source_id': 'M1'},
#     {'claim_text': 'Zurich rental index YoY: +2.1%', 'source_id': 'M1'},
#     {'claim_text': 'Local median advertised rent: CHF 37/m²',
#      'source_id': 'M2'}],
#    'facts_used': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'warnings': []},
#   'validation_issues': ["Meta mismatch: 'Elevator present in the building' does not contain 'True'",
#    "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'",
#    "Claim '4 primary schools within 1.2 km' not found in snippet S1",
#    "Claim '3 parks within a 10-minute walk' not found in snippet S1",
#    "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2",
#    "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1",
#    "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1",
#    "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]},
#  'expats': {'planner': {'audience': 'expats',
#    'listing_type': 'rental',
#    'positioning': {'primary_angle': 'Clear, factual presentation of a move-in-ready 3.5-room rental in Wiedikon, Zurich, highlighting practical features and transport links relevant to newcomers.',
#     'secondary_angle': 'Contextualise cost and market position for comparison (local median rent, district vacancy and rental index) so expats can assess value quickly.'},
#    'outline': [{'section': 'Headline / Quick facts',
#      'goal': 'Provide the most important facts at a glance (type, city/neighbourhood, size, rooms, monthly rent, availability date).'},
#     {'section': 'Key financials',
#      'goal': 'List rent, utilities, optional parking cost, and rent per m² so the reader can immediately assess monthly outlay.'},
#     {'section': 'Apartment layout & features',
#      'goal': 'Describe rooms count, total living area, balcony size, building year, elevator, and heating system — practical details for move-in planning.'},
#     {'section': 'Location & transport',
#      'goal': 'State neighbourhood, proximity to nearest S-Bahn station and its peak frequency to explain commuting options for professionals.'},
#     {'section': 'Local amenities',
#      'goal': 'Mention counts of nearby primary schools and parks (using retrieved data) so families/expats understand local services without implying quality rankings.'},
#     {'section': 'Market context',
#      'goal': 'Provide district-level vacancy estimate and Zurich rental index YoY figure plus local median advertised rent to contextualise the asking rent.'},
#     {'section': 'Availability & next steps',
#      'goal': 'Confirm the available-from date and instruct readers on contacting the agent/landlord for applications, viewings and confirmation of figures.'},
#     {'section': 'Mandatory notes & disclaimers',
#      'goal': 'Include required legal/accuracy disclaimers and explicitly state which figures must be confirmed with the landlord.'}],
#    'facts_to_use': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'must_cite': [{'claim_type': 'monthly_rent',
#      'rule': 'Cite meta.rent_chf (CHF 3150) when stating the monthly rent.'},
#     {'claim_type': 'utilities_cost',
#      'rule': 'Cite meta.utilities_chf (CHF 250) when stating typical utilities/charges.'},
#     {'claim_type': 'parking_cost',
#      'rule': 'Cite meta.parking_chf (CHF 180) when listing parking as a priced optional item.'},
#     {'claim_type': 'availability_date',
#      'rule': 'Cite meta.available_from (2026-04-01) when stating earliest move-in date.'},
#     {'claim_type': 'size_and_layout',
#      'rule': 'Cite meta.size_m2 (82 m²), meta.rooms (3.5) and meta.balcony_m2 (7 m²) for all statements about area and layout.'},
#     {'claim_type': 'building_features',
#      'rule': "Cite meta.year_built (2016), meta.elevator (True) and meta.heating ('Underfloor heating') when describing the building and systems."},
#     {'claim_type': 'transport_proximity_and_frequency',
#      'rule': "Cite S2: 'Nearest S-Bahn station within 650 m. Peak frequency approx every 7-10 minutes.' for any claims about public transport access."},
#     {'claim_type': 'local_amenities_counts',
#      'rule': "Cite S1 for counts: 'Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3.' when mentioning nearby schools and parks."},
#     {'claim_type': 'market_context',
#      'rule': 'Cite M1 and M2 when referencing district vacancy (M1: 0.7%), Zurich rental index YoY (M1: +2.1%) and local median advertised rent (M2: CHF 37/m²).'},
#     {'claim_type': 'rent_per_m2',
#      'rule': 'Cite meta.rent_per_m2 (CHF 38.4/m²) when providing per-square-metre pricing and compare directly to M2 (CHF 37/m²) if including a comparison.'}],
#    'must_avoid': [{'type': 'guarantees_or_investment_claims',
#      'rule': "Do not state or imply any guarantees about future price increases, returns, or that the property 'will increase in value.'"},
#     {'type': 'safety_superlatives',
#      'rule': "Avoid absolute safety claims (e.g., 'safest', 'perfectly safe'); do not make any crime/safety superlative statements."},
#     {'type': 'school_quality_claims',
#      'rule': 'Do not claim or imply school quality or rankings. Only present the raw counts from S1 (number of primary schools) without qualitative statements.'},
#     {'type': 'invented_pois_or_commute_times',
#      'rule': 'Do not invent or state commute times or other POIs not present in the FACTS block. Only use the S2 proximity/frequency and S1 counts for amenities.'},
#     {'type': 'subjective_absolutes',
#      'rule': "Avoid words like 'best', 'most desirable', 'ideal' unless supported by explicit ranking data (none provided). Use neutral, factual language."}],
#    'required_disclaimers': ['All figures are based on the provided listing data and retrieved sources; prospective tenants should confirm details (rent, utilities, parking availability and costs, and availability date) with the landlord or agent.',
#     'Market figures (vacancy, rental index, median rent) are district/area-level indicators and do not guarantee future performance or suitability.',
#     'Counts of nearby schools and parks are factual counts from the retrieved data and do not indicate quality or specific services.'],
#    'style': {'tone': 'professional',
#     'length_words': [180, 280],
#     'format': "Use clear short paragraphs and bullet lists for key facts; include one-line headline and a concise closing 'next steps' instruction."}},
#   'writer': {'audience': 'expats',
#    'listing_type': 'rental',
#    'title': '3.5-room rental in Wiedikon, Zurich — 82 m² — CHF 3,150/month — Available 2026-04-01',
#    'description': 'Headline / Quick facts\nMove-in-ready 3.5-room rental in Wiedikon, Zurich. Living area: 82 m². Monthly rent: CHF 3,150. Available from 2026-04-01.\n\nHighlights\n- 3.5 rooms and 82 m² of living space\n- Balcony of 7 m²\n- Close to S-Bahn (see transport details below)\n\nKey financials\nMonthly rent: CHF 3,150. Typical utilities/charges: CHF 250/month. Optional parking (if available): CHF 180/month. Asking rent per m²: CHF 38.4/m².\n\nApartment layout & features\nThe apartment offers 3.5 rooms across 82 m² with a 7 m² balcony. The building was completed in 2016 and includes an elevator. Heating is provided via underfloor heating.\n\nLocation & transport\nLocated in the Wiedikon neighbourhood of Zurich. The nearest S-Bahn station is within 650 m; peak service frequency is approximately every 7–10 minutes.\n\nLocal amenities\nThere are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk according to local counts.\n\nMarket context\nDistrict-level vacancy is estimated at 0.7%, and the Zurich rental index year-on-year is +2.1%. Local median advertised rent is CHF 37/m²; this listing is CHF 38.4/m².\n\nAvailability & next steps\nAvailable from 2026-04-01. Please contact the landlord or agent to request an application form or to arrange a viewing and to confirm figures.\n\nMandatory notes & disclaimers\nAll figures are based on the provided listing data and retrieved sources; prospective tenants should confirm details (rent, utilities, parking availability and costs, and availability date) with the landlord or agent. Market figures are district/area-level indicators and do not guarantee future performance or suitability. Counts of nearby schools and parks are factual counts from the retrieved data and do not indicate quality or specific services.',
#    'highlights': ['3.5 rooms and 82 m² living area',
#     '7 m² balcony',
#     'CHF 3,150 monthly rent'],
#    'claims': [{'claim_text': 'Monthly rent: CHF 3,150.',
#      'source_id': 'meta.rent_chf'},
#     {'claim_text': 'Utilities (estimated): CHF 250/month.',
#      'source_id': 'meta.utilities_chf'},
#     {'claim_text': 'Optional parking (if available): CHF 180/month.',
#      'source_id': 'meta.parking_chf'},
#     {'claim_text': 'Available from 2026-04-01.',
#      'source_id': 'meta.available_from'},
#     {'claim_text': '3.5 rooms.', 'source_id': 'meta.rooms'},
#     {'claim_text': 'Living area: 82 m².', 'source_id': 'meta.size_m2'},
#     {'claim_text': 'Balcony: 7 m².', 'source_id': 'meta.balcony_m2'},
#     {'claim_text': 'Year built: 2016.', 'source_id': 'meta.year_built'},
#     {'claim_text': 'Elevator: yes.', 'source_id': 'meta.elevator'},
#     {'claim_text': 'Heating: Underfloor heating.',
#      'source_id': 'meta.heating'},
#     {'claim_text': 'Nearest S-Bahn station within 650 m; peak frequency approx every 7-10 minutes.',
#      'source_id': 'S2'},
#     {'claim_text': 'Primary schools within 1.2 km: 4.', 'source_id': 'S1'},
#     {'claim_text': 'Parks within 10-minute walk: 3.', 'source_id': 'S1'},
#     {'claim_text': 'District-level vacancy estimate: 0.7%.',
#      'source_id': 'M1'},
#     {'claim_text': 'Zurich rental index YoY: +2.1%.', 'source_id': 'M1'},
#     {'claim_text': 'Local median advertised rent: CHF 37/m².',
#      'source_id': 'M2'},
#     {'claim_text': 'Rent per m²: CHF 38.4/m².',
#      'source_id': 'meta.rent_per_m2'}],
#    'facts_used': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'warnings': ['Prospective tenants must confirm rent, utilities, parking availability and costs, and availability date with the landlord or agent.',
#     'Market figures are district/area-level indicators and do not guarantee future performance or suitability.',
#     'Counts of nearby schools and parks are factual counts and do not indicate quality or specific services.']},
#   'validation_issues': ["Meta mismatch: 'Elevator present in the building' does not contain 'True'",
#    "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'",
#    "Claim '4 primary schools within 1.2 km' not found in snippet S1",
#    "Claim '3 parks within a 10-minute walk' not found in snippet S1",
#    "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2",
#    "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1",
#    "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1",
#    "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]},
#  'students': {'planner': {'audience': 'students',
#    'listing_type': 'rental',
#    'positioning': {'primary_angle': 'Affordable, well-connected 3.5-room apartment suitable for students (single or shared occupancy) looking for modern, low-maintenance housing in Zurich-Wiedikon.',
#     'secondary_angle': 'Contemporary 2016 building with elevator, underfloor heating and a private balcony — clear cost breakdown for budgeting.'},
#    'outline': [{'section': 'Headline / Leading sentence',
#      'goal': 'One-line summary that highlights type, location, rent and availability (for quick scanning).'},
#     {'section': 'Quick facts (specs snapshot)',
#      'goal': 'Bullet list of core numbers for easy comparison: rooms, size, balcony, floor access, year built, heating, monthly rent and recurring costs.'},
#     {'section': 'Who this suits',
#      'goal': 'Concise statement explaining suitability for students (e.g., study-friendly layout, shared living possible) without guarantees or superlatives.'},
#     {'section': 'Transport and local amenities',
#      'goal': 'Fact-based proximity info: distance to nearest S-Bahn, peak frequency, counts of nearby primary schools and parks (from retrieved facts). Avoid implying commute times to unspecified POIs.'},
#     {'section': 'Costs & practicalities',
#      'goal': 'Clear itemized monthly cost breakdown: base rent, utilities, optional parking fee, and rent per m² for market context. Note any separate agreements (parking).'},
#     {'section': 'Availability & next steps',
#      'goal': 'State the available-from date and instruct reader to contact the listing agent/landlord to confirm details and schedule viewings. Include verification reminder.'}],
#    'facts_to_use': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'must_cite': [{'claim_type': 'monthly_rent',
#      'rule': 'When stating the monthly rent, cite meta.rent_chf.'},
#     {'claim_type': 'availability_date',
#      'rule': 'When stating when the apartment is available, cite meta.available_from.'},
#     {'claim_type': 'size_and_layout',
#      'rule': 'When stating rooms, living area or balcony size, cite meta.rooms, meta.size_m2 and meta.balcony_m2.'},
#     {'claim_type': 'building_features',
#      'rule': 'When describing year built, elevator or heating, cite meta.year_built, meta.elevator and meta.heating.'},
#     {'claim_type': 'transport_proximity_and_frequency',
#      'rule': 'When mentioning nearest S-Bahn station distance and peak frequency, cite S2.'},
#     {'claim_type': 'local_amenities_counts',
#      'rule': 'When stating counts of nearby primary schools and parks, cite S1.'},
#     {'claim_type': 'market_context',
#      'rule': 'When referencing district vacancy, rental index change, or local median rent comparison, cite M1 and M2 as appropriate (e.g., vacancy estimate, YoY index, median rent CHF/m²).'},
#     {'claim_type': 'utilities_and_parking_costs',
#      'rule': 'When listing utilities and parking monthly amounts, cite meta.utilities_chf and meta.parking_chf.'}],
#    'must_avoid': [{'type': 'guarantee_claims',
#      'rule': 'Do not make any guarantees (e.g., guaranteed affordability, guaranteed return on investment, guaranteed future availability).'},
#     {'type': 'safety_superlatives',
#      'rule': "Avoid claims about safety quality or using superlatives like 'safest' or 'perfectly safe'."},
#     {'type': 'school_quality',
#      'rule': 'Do not claim or infer school quality or rankings; only use provided counts of nearby primary schools (S1).'},
#     {'type': 'invented_pois_commute',
#      'rule': 'Do not invent points of interest, commute times, or distances not present in the FACTS block. Use only S2 for S-Bahn distance/frequency and S1 for school/park counts.'},
#     {'type': 'subjective_absolutes',
#      'rule': "Avoid subjective absolute terms (e.g., 'best', 'most desirable') unless supported by explicit ranking data from provided facts (none present)."},
#     {'type': 'investment_advice',
#      'rule': 'Do not present the listing as an investment opportunity or suggest future capital appreciation.'}],
#    'required_disclaimers': ['All listed facts are based on the provided data; prospective tenants should verify details with the landlord or listing agent before signing.',
#     'Availability, rent and ancillary costs are subject to change and must be confirmed with the property manager.',
#     'Transport frequency and nearby amenity counts are approximate and based on the retrieved sources provided; verify current schedules and local services.'],
#    'style': {'tone': 'professional',
#     'length_words': [120, 180],
#     'format': "Use a short headline (1 sentence), a concise bullet 'Quick facts' section, two short paragraphs for neighborhood/transport and costs/practicalities, and one closing sentence for availability and next steps."}},
#   'writer': {'audience': 'students',
#    'listing_type': 'rental',
#    'title': '3.5-room rental in Zurich-Wiedikon — CHF 3,150/month, available 2026-04-01',
#    'description': '3.5-room apartment in Zurich-Wiedikon — CHF 3,150/month, available from 2026-04-01.\n\nQuick facts:\n- Rooms: 3.5\n- Living area: 82 m²; Balcony: 7 m²\n- Year built: 2016; Elevator; Underfloor heating\n- Base rent: CHF 3,150/month; Utilities: CHF 250/month; Parking (optional): CHF 180/month; Rent per m²: CHF 38.4\n\nWho this suits\nSuitable for students seeking single or shared occupancy in a modern, low-maintenance apartment layout.\n\nTransport and local amenities\nNearest S-Bahn station is within 650 m, with peak frequency approx every 7-10 minutes. There are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk.\n\nCosts & practicalities\nMonthly costs: base rent CHF 3,150 plus utilities CHF 250; parking is available separately at CHF 180/month. For market context, local median advertised rent is CHF 37/m²; district-level vacancy is 0.7% and the Zurich rental index is +2.1% year-on-year.\n\nAvailability & next steps\nAvailable from 2026-04-01 — please contact the listing agent or landlord to confirm details and arrange a viewing. All listed facts are based on the provided data; prospective tenants should verify details with the landlord or listing agent before signing. Availability, rent and ancillary costs are subject to change and must be confirmed with the property manager. Transport frequency and nearby amenity counts are approximate and based on the retrieved sources provided; verify current schedules and local services.',
#    'highlights': ['3.5 rooms in Zurich-Wiedikon',
#     '82 m² living area with 7 m² balcony',
#     'Modern 2016 building with elevator and underfloor heating',
#     'Clear monthly costs: CHF 3,150 rent + CHF 250 utilities (parking CHF 180)'],
#    'claims': [{'claim_text': 'Monthly rent CHF 3,150',
#      'source_id': 'meta.rent_chf'},
#     {'claim_text': 'Available from 2026-04-01',
#      'source_id': 'meta.available_from'},
#     {'claim_text': 'Rooms: 3.5', 'source_id': 'meta.rooms'},
#     {'claim_text': 'Living area: 82 m²', 'source_id': 'meta.size_m2'},
#     {'claim_text': 'Balcony: 7 m²', 'source_id': 'meta.balcony_m2'},
#     {'claim_text': 'Year built: 2016', 'source_id': 'meta.year_built'},
#     {'claim_text': 'Elevator: true', 'source_id': 'meta.elevator'},
#     {'claim_text': 'Heating: Underfloor heating', 'source_id': 'meta.heating'},
#     {'claim_text': 'Rent per m²: CHF 38.4', 'source_id': 'meta.rent_per_m2'},
#     {'claim_text': 'Utilities: CHF 250/month',
#      'source_id': 'meta.utilities_chf'},
#     {'claim_text': 'Parking: CHF 180/month', 'source_id': 'meta.parking_chf'},
#     {'claim_text': 'Nearest S-Bahn station within 650 m; peak frequency approx every 7-10 minutes',
#      'source_id': 'S2'},
#     {'claim_text': 'Primary schools within 1.2 km: 4; Parks within 10-minute walk: 3',
#      'source_id': 'S1'},
#     {'claim_text': 'District-level vacancy estimate: 0.7%; Zurich rental index YoY: +2.1%',
#      'source_id': 'M1'},
#     {'claim_text': 'Local median advertised rent: CHF 37/m²',
#      'source_id': 'M2'}],
#    'facts_used': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'warnings': []},
#   'validation_issues': ["Meta mismatch: 'Elevator present in the building' does not contain 'True'",
#    "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'",
#    "Claim '4 primary schools within 1.2 km' not found in snippet S1",
#    "Claim '3 parks within a 10-minute walk' not found in snippet S1",
#    "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2",
#    "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1",
#    "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1",
#    "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]},
#  'investors': {'planner': {'audience': 'investors',
#    'listing_type': 'rental',
#    'positioning': {'primary_angle': 'Investment-oriented financial snapshot emphasizing rental income, operating costs, and local market indicators.',
#     'secondary_angle': 'Concise location and building features supporting rental demand (public transport proximity, nearby schools/parks, recent construction).'},
#    'outline': [{'section': 'Investment snapshot (lead)',
#      'goal': "Present the unit's core financials and physical metrics up front so an investor can quickly assess cash-flow components: monthly rent (CHF), rent per m², unit size, rooms, parking charge, utilities, and availability date."},
#     {'section': 'Market context and comparables',
#      'goal': 'Summarize local market indicators that inform demand and pricing: district vacancy estimate, recent rental index change, and local median advertised rent — all cited to sources. Avoid projecting returns or guarantees.'},
#     {'section': 'Location & transport',
#      'goal': 'Describe neighbourhood (Wiedikon, Zurich) and immediate transport access using provided data: distance to nearest S-Bahn and peak frequency. Note counts of nearby primary schools and parks as indicators of tenant profiles; cite sources.'},
#     {'section': 'Building & unit features',
#      'goal': 'List objective building and apartment characteristics that affect rental appeal and maintenance: year built, elevator, underfloor heating, balcony size, room count, and total m². Only state facts from meta.'},
#     {'section': 'Financials & operating costs (detail)',
#      'goal': 'Break down monthly cost items (rent, utilities, parking) and present rent per m² for comparison with local median; cite M2 when referencing local median. Avoid calculating or implying ROI or future appreciation.'},
#     {'section': 'Suggested due diligence points',
#      'goal': 'Provide a concise checklist of items for investors to verify (current tenancy status, operating costs detail, maintenance history, charge allocation, confirmation of availability). These are prompts, not guarantees.'},
#     {'section': 'Call to action / contact instruction',
#      'goal': 'Ask reader to contact the listing agent for up-to-date tenancy, viewing arrangements and final figures; remind them to verify market data and availability.'}],
#    'facts_to_use': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'must_cite': [{'claim_type': 'listing_details',
#      'rule': 'When stating apartment-specific facts (size, rooms, balcony m², year built, elevator, heating, rent, rent per m², utilities, parking, available from), cite the corresponding meta fields from the FACTS block.'},
#     {'claim_type': 'transport',
#      'rule': 'When referencing distance to public transport and service frequency, cite retrieved item S2 (nearest S-Bahn station within 650 m; peak frequency approx every 7–10 minutes).'},
#     {'claim_type': 'amenities',
#      'rule': 'When referencing counts of nearby primary schools and parks, cite retrieved item S1 (Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3).'},
#     {'claim_type': 'market_data',
#      'rule': 'When referencing district vacancy estimate or rental index YoY, cite retrieved item M1 (district-level vacancy estimate: 0.7%; Zurich rental index YoY +2.1%).'},
#     {'claim_type': 'local_rent_comparison',
#      'rule': "When comparing the unit's rent per m² to local advertised levels, cite retrieved item M2 (Local median advertised rent: CHF 37/m²)."}],
#    'must_avoid': [{'type': 'no_guarantees',
#      'rule': "Do not state or imply any guaranteed returns, guaranteed occupancy, guaranteed future rent growth, or that the investment 'will' increase in value."},
#     {'type': 'no_safety_superlatives',
#      'rule': "Do not use absolute safety claims or superlatives about safety or crime levels (e.g., 'safest', 'completely safe')."},
#     {'type': 'no_school_quality_claims',
#      'rule': 'Do not claim school quality or rankings unless supported by an explicit source — only use S1 counts (number of primary schools) as factual proximity indicators, not qualitative judgments about school quality.'},
#     {'type': 'no_invented_pois_or_commute_times',
#      'rule': 'Do not invent points of interest, distances, or commute times not present in the FACTS block. Use only S1 and S2 for nearby amenities and transport metrics.'},
#     {'type': 'no_subjective_absolutes',
#      'rule': "Avoid subjective absolutes or superlatives about desirability (e.g., 'best', 'ideal') unless a retrieved, cited ranking supports it; do not invent such rankings."}],
#    'required_disclaimers': ['This summary is for informational purposes and not investment advice. Past market performance is not a guarantee of future results.',
#     'Market statistics and proximity data are cited from the provided sources (M1, M2, S1, S2) and should be independently verified.',
#     'Availability, rent and charges are subject to change; confirm current details and tenancy status with the listing agent before making decisions.',
#     'No guarantees are made regarding rental income, occupancy rates or capital appreciation.'],
#    'style': {'tone': 'professional',
#     'length_words': [180, 320],
#     'format': 'Use short labeled sections or bullets for numeric facts; keep sentences factual and measurable.'}},
#   'writer': {'audience': 'investors',
#    'listing_type': 'rental',
#    'title': 'Investment snapshot — 3.5‑room rental in Wiedikon, Zurich',
#    'description': "Investment snapshot (lead):\n• Monthly rent: CHF 3150. • Rent per m²: CHF 38.4. • Size: 82 m². • Rooms: 3.5. • Parking charge: CHF 180. • Utilities: CHF 250. • Available from: 2026-04-01.\n\nMarket context and comparables:\nDistrict-level vacancy is 0.7% and the Zurich rental index is +2.1% year-on-year. Local median advertised rent is CHF 37/m², providing a direct point of comparison for this unit's rent per m².\n\nLocation & transport:\nThe apartment is in Wiedikon, Zurich. Nearest S-Bahn station is within 650 m; peak service frequency is approximately every 7–10 minutes. There are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk, which indicate local amenity density.\n\nBuilding & unit features:\nYear built: 2016. Elevator: yes. Heating: underfloor heating. Balcony size: 7 m². Apartment: 3.5 rooms, 82 m².\n\nFinancials & operating costs (detail):\nMonthly rent: CHF 3150. Utilities: CHF 250. Parking charge: CHF 180. Rent per m²: CHF 38.4 versus local median advertised CHF 37/m².\n\nSuggested due diligence points:\n• Confirm current tenancy status and lease terms. • Verify detailed operating cost breakdown. • Review maintenance and warranty history for the building. • Confirm charge allocation and parking arrangement. • Re-confirm availability date and move-in conditions.\n\nCall to action / contact instruction:\nContact the listing agent for up-to-date tenancy, viewing arrangements and final figures. Verify market statistics and availability before making investment decisions.\n\nDisclaimers:\nThis summary is for informational purposes and not investment advice. Past market performance is not a guarantee of future results. Market statistics and proximity data are cited from the provided sources (M1, M2, S1, S2) and should be independently verified. Availability, rent and charges are subject to change; confirm current details and tenancy status with the listing agent before making decisions. No guarantees are made regarding rental income, occupancy rates or capital appreciation.",
#    'highlights': ['Monthly rent: CHF 3150 (rental)',
#     'Size: 82 m² — 3.5 rooms with 7 m² balcony',
#     'Built 2016; elevator and underfloor heating',
#     'Nearest S-Bahn within 650 m; peak frequency ~7–10 minutes',
#     'District vacancy 0.7%; local median advertised rent CHF 37/m²'],
#    'claims': [{'claim_text': 'Monthly rent: CHF 3150',
#      'source_id': 'meta.rent_chf'},
#     {'claim_text': 'Rent per m²: CHF 38.4', 'source_id': 'meta.rent_per_m2'},
#     {'claim_text': 'Size: 82 m²', 'source_id': 'meta.size_m2'},
#     {'claim_text': 'Rooms: 3.5', 'source_id': 'meta.rooms'},
#     {'claim_text': 'Parking charge: CHF 180', 'source_id': 'meta.parking_chf'},
#     {'claim_text': 'Utilities: CHF 250', 'source_id': 'meta.utilities_chf'},
#     {'claim_text': 'Available from: 2026-04-01',
#      'source_id': 'meta.available_from'},
#     {'claim_text': 'Balcony size: 7 m²', 'source_id': 'meta.balcony_m2'},
#     {'claim_text': 'Year built: 2016', 'source_id': 'meta.year_built'},
#     {'claim_text': 'Elevator: True', 'source_id': 'meta.elevator'},
#     {'claim_text': 'Heating: Underfloor heating', 'source_id': 'meta.heating'},
#     {'claim_text': 'Nearest S-Bahn station within 650 m', 'source_id': 'S2'},
#     {'claim_text': 'Peak service frequency approximately every 7–10 minutes',
#      'source_id': 'S2'},
#     {'claim_text': 'Primary schools within 1.2 km: 4', 'source_id': 'S1'},
#     {'claim_text': 'Parks within 10-minute walk: 3', 'source_id': 'S1'},
#     {'claim_text': 'District-level vacancy estimate: 0.7%', 'source_id': 'M1'},
#     {'claim_text': 'Zurich rental index year-on-year: +2.1%',
#      'source_id': 'M1'},
#     {'claim_text': 'Local median advertised rent: CHF 37/m²',
#      'source_id': 'M2'}],
#    'facts_used': ['meta.listing_type',
#     'meta.city',
#     'meta.neighborhood',
#     'meta.rooms',
#     'meta.size_m2',
#     'meta.balcony_m2',
#     'meta.year_built',
#     'meta.elevator',
#     'meta.heating',
#     'meta.rent_chf',
#     'meta.rent_per_m2',
#     'meta.utilities_chf',
#     'meta.parking_chf',
#     'meta.available_from',
#     'S1',
#     'S2',
#     'M1',
#     'M2'],
#    'warnings': []},
#   'validation_issues': ["Meta mismatch: 'Elevator present in the building' does not contain 'True'",
#    "Meta mismatch: 'Monthly rent CHF 3,150' does not contain '3150'",
#    "Claim '4 primary schools within 1.2 km' not found in snippet S1",
#    "Claim '3 parks within a 10-minute walk' not found in snippet S1",
#    "Claim 'Peak frequency approximately every 7-10 minutes' not found in snippet S2",
#    "Claim 'District-level vacancy estimate 0.7%' not found in snippet M1",
#    "Claim 'Zurich rental index year-on-year +2.1%' not found in snippet M1",
#    "Claim 'Local median advertised rent CHF 37/m²' not found in snippet M2"]}}

# %%
for audience in audiences:
    print("\n" + "="*80)
    print(f'Audience: {audience}')
    print(f'Title: {results[audience]['writer']['title']}')
    print(f'Description:\n {results[audience]['writer']['description']}')
# Out:
# ================================================================================
# Audience: families
# Title: Family-friendly 3.5-room rental in Wiedikon — available 2026-04-01 at CHF 3,150/month
# Description:
#  Headline
# Family-friendly 3.5-room apartment in Wiedikon — available 2026-04-01 at CHF 3,150/month.
#
# Quick facts (at-a-glance)
# Type: Rental in Zurich, Wiedikon. 3.5 rooms, 82 m² living space, 7 m² balcony. Built 2016. Elevator present. Heating: Underfloor heating. Rent CHF 3,150 / month; utilities CHF 250; parking CHF 180. Available from 2026-04-01.
#
# Why it works for families
# The 3.5-room layout and 82 m² provide clear family living space, plus a 7 m² balcony for outdoor time. Primary schools within 1.2 km: 4. Parks within 10-minute walk: 3.
#
# Practical features & comfort
# The building was completed in 2016 and includes an elevator. The apartment benefits from underfloor heating for even warmth and a practical 3.5-room arrangement.
#
# Transport & local access
# Nearest S-Bahn station within 650 m. Peak frequency approx every 7-10 minutes.
#
# Costs & availability
# Monthly rent CHF 3,150; utilities CHF 250; parking CHF 180. Available from 2026-04-01.
#
# Local market context
# District-level vacancy estimate: 0.7%. Zurich rental index YoY: +2.1%. Local median advertised rent: CHF 37/m².
#
# Next steps / contact prompt
# Request a viewing or contact the listing agent to learn more. All facts and figures are taken from the provided data and should be independently verified prior to signing any lease. Monthly utilities and parking fees are quoted separately and subject to change; confirm exact charges with the listing agent. Availability date is as stated (2026-04-01) and should be confirmed with the agent at inquiry.
#
# ================================================================================
# Audience: expats
# Title: 3.5-room rental in Wiedikon, Zurich — 82 m² — CHF 3,150/month — Available 2026-04-01
# Description:
#  Headline / Quick facts
# Move-in-ready 3.5-room rental in Wiedikon, Zurich. Living area: 82 m². Monthly rent: CHF 3,150. Available from 2026-04-01.
#
# Highlights
# - 3.5 rooms and 82 m² of living space
# - Balcony of 7 m²
# - Close to S-Bahn (see transport details below)
#
# Key financials
# Monthly rent: CHF 3,150. Typical utilities/charges: CHF 250/month. Optional parking (if available): CHF 180/month. Asking rent per m²: CHF 38.4/m².
#
# Apartment layout & features
# The apartment offers 3.5 rooms across 82 m² with a 7 m² balcony. The building was completed in 2016 and includes an elevator. Heating is provided via underfloor heating.
#
# Location & transport
# Located in the Wiedikon neighbourhood of Zurich. The nearest S-Bahn station is within 650 m; peak service frequency is approximately every 7–10 minutes.
#
# Local amenities
# There are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk according to local counts.
#
# Market context
# District-level vacancy is estimated at 0.7%, and the Zurich rental index year-on-year is +2.1%. Local median advertised rent is CHF 37/m²; this listing is CHF 38.4/m².
#
# Availability & next steps
# Available from 2026-04-01. Please contact the landlord or agent to request an application form or to arrange a viewing and to confirm figures.
#
# Mandatory notes & disclaimers
# All figures are based on the provided listing data and retrieved sources; prospective tenants should confirm details (rent, utilities, parking availability and costs, and availability date) with the landlord or agent. Market figures are district/area-level indicators and do not guarantee future performance or suitability. Counts of nearby schools and parks are factual counts from the retrieved data and do not indicate quality or specific services.
#
# ================================================================================
# Audience: students
# Title: 3.5-room rental in Zurich-Wiedikon — CHF 3,150/month, available 2026-04-01
# Description:
#  3.5-room apartment in Zurich-Wiedikon — CHF 3,150/month, available from 2026-04-01.
#
# Quick facts:
# - Rooms: 3.5
# - Living area: 82 m²; Balcony: 7 m²
# - Year built: 2016; Elevator; Underfloor heating
# - Base rent: CHF 3,150/month; Utilities: CHF 250/month; Parking (optional): CHF 180/month; Rent per m²: CHF 38.4
#
# Who this suits
# Suitable for students seeking single or shared occupancy in a modern, low-maintenance apartment layout.
#
# Transport and local amenities
# Nearest S-Bahn station is within 650 m, with peak frequency approx every 7-10 minutes. There are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk.
#
# Costs & practicalities
# Monthly costs: base rent CHF 3,150 plus utilities CHF 250; parking is available separately at CHF 180/month. For market context, local median advertised rent is CHF 37/m²; district-level vacancy is 0.7% and the Zurich rental index is +2.1% year-on-year.
#
# Availability & next steps
# Available from 2026-04-01 — please contact the listing agent or landlord to confirm details and arrange a viewing. All listed facts are based on the provided data; prospective tenants should verify details with the landlord or listing agent before signing. Availability, rent and ancillary costs are subject to change and must be confirmed with the property manager. Transport frequency and nearby amenity counts are approximate and based on the retrieved sources provided; verify current schedules and local services.
#
# ================================================================================
# Audience: investors
# Title: Investment snapshot — 3.5‑room rental in Wiedikon, Zurich
# Description:
#  Investment snapshot (lead):
# • Monthly rent: CHF 3150. • Rent per m²: CHF 38.4. • Size: 82 m². • Rooms: 3.5. • Parking charge: CHF 180. • Utilities: CHF 250. • Available from: 2026-04-01.
#
# Market context and comparables:
# District-level vacancy is 0.7% and the Zurich rental index is +2.1% year-on-year. Local median advertised rent is CHF 37/m², providing a direct point of comparison for this unit's rent per m².
#
# Location & transport:
# The apartment is in Wiedikon, Zurich. Nearest S-Bahn station is within 650 m; peak service frequency is approximately every 7–10 minutes. There are 4 primary schools within 1.2 km and 3 parks within a 10-minute walk, which indicate local amenity density.
#
# Building & unit features:
# Year built: 2016. Elevator: yes. Heating: underfloor heating. Balcony size: 7 m². Apartment: 3.5 rooms, 82 m².
#
# Financials & operating costs (detail):
# Monthly rent: CHF 3150. Utilities: CHF 250. Parking charge: CHF 180. Rent per m²: CHF 38.4 versus local median advertised CHF 37/m².
#
# Suggested due diligence points:
# • Confirm current tenancy status and lease terms. • Verify detailed operating cost breakdown. • Review maintenance and warranty history for the building. • Confirm charge allocation and parking arrangement. • Re-confirm availability date and move-in conditions.
#
# Call to action / contact instruction:
# Contact the listing agent for up-to-date tenancy, viewing arrangements and final figures. Verify market statistics and availability before making investment decisions.
#
# Disclaimers:
# This summary is for informational purposes and not investment advice. Past market performance is not a guarantee of future results. Market statistics and proximity data are cited from the provided sources (M1, M2, S1, S2) and should be independently verified. Availability, rent and charges are subject to change; confirm current details and tenancy status with the listing agent before making decisions. No guarantees are made regarding rental income, occupancy rates or capital appreciation.
